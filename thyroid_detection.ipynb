# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("thyroidDF.csv")

# %%
df.head()
# Out:
#    age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick pregnant  \
# 0   29   F            f                  f                   f    f        f
# 1   29   F            f                  f                   f    f        f
# 2   41   F            f                  f                   f    f        f
# 3   36   F            f                  f                   f    f        f
# 4   32   F            f                  f                   f    f        f
#
#   thyroid_surgery I131_treatment query_hypothyroid  ...    TT4 T4U_measured  \
# 0               f              f                 t  ...    NaN            f
# 1               f              f                 f  ...  128.0            f
# 2               f              f                 f  ...    NaN            f
# 3               f              f                 f  ...    NaN            f
# 4               f              f                 f  ...    NaN            f
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9172 entries, 0 to 9171
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  9172 non-null   int64
#  1   sex                  8865 non-null   object
#  2   on_thyroxine         9172 non-null   object
#  3   query_on_thyroxine   9172 non-null   object
#  4   on_antithyroid_meds  9172 non-null   object
#  5   sick                 9172 non-null   object
#  6   pregnant             9172 non-null   object
#  7   thyroid_surgery      9172 non-null   object
#  8   I131_treatment       9172 non-null   object
#  9   query_hypothyroid    9172 non-null   object
#  10  query_hyperthyroid   9172 non-null   object
#  11  lithium              9172 non-null   object
#  12  goitre               9172 non-null   object
#  13  tumor                9172 non-null   object
#  14  hypopituitary        9172 non-null   object
# ...

# %%
df.describe()
# Out:
#                 age          TSH           T3          TT4          T4U  \
# count   9172.000000  8330.000000  6568.000000  8730.000000  8363.000000
# mean      73.555822     5.218403     1.970629   108.700305     0.976056
# std     1183.976718    24.184006     0.887579    37.522670     0.200360
# min        1.000000     0.005000     0.050000     2.000000     0.170000
# 25%       37.000000     0.460000     1.500000    87.000000     0.860000
# 50%       55.000000     1.400000     1.900000   104.000000     0.960000
# 75%       68.000000     2.700000     2.300000   126.000000     1.065000
# max    65526.000000   530.000000    18.000000   600.000000     2.330000
#
#                FTI         TBG    patient_id
# count  8370.000000  349.000000  9.172000e+03
# mean    113.640746   29.870057  8.529473e+08
# std      41.551650   21.080504  7.581969e+06
# min       1.400000    0.100000  8.408010e+08
# 25%      93.000000   21.000000  8.504090e+08
# 50%     109.000000   26.000000  8.510040e+08
# ...

# %%
features=df[['age', 'lithium',
       'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH',
        'T3','TT4', 'T4U',
        'FTI',  'TBG']]
features
# Out:
#       age lithium goitre tumor hypopituitary psych  TSH   T3    TT4   T4U  \
# 0      29       f      f     f             f     f  0.3  NaN    NaN   NaN
# 1      29       f      f     f             f     f  1.6  1.9  128.0   NaN
# 2      41       f      f     f             f     f  NaN  NaN    NaN   NaN
# 3      36       f      f     f             f     f  NaN  NaN    NaN   NaN
# 4      32       f      f     f             f     f  NaN  NaN    NaN   NaN
# ...   ...     ...    ...   ...           ...   ...  ...  ...    ...   ...
# 9167   56       f      f     f             f     f  NaN  NaN   64.0  0.83
# 9168   22       f      f     f             f     f  NaN  NaN   91.0  0.92
# 9169   69       f      f     f             f     f  NaN  NaN  113.0  1.27
# 9170   47       f      f     f             f     f  NaN  NaN   75.0  0.85
# 9171   31       f      f     f             f     f  NaN  NaN   66.0  1.02
#
#        FTI   TBG
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN  11.0
# ...

# %%
cols=['lithium','goitre', 'tumor', 'hypopituitary', 'psych']
encoded={'f':0,"t":1}
for col in cols: 
    features[col]=[encoded[i] for i in features[col].values]
# Out:
# <ipython-input-12-947d1b2a82d1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[col]=[encoded[i] for i in features[col].values]

# %%
features
# Out:
#       age  lithium  goitre  tumor  hypopituitary  psych  TSH   T3    TT4  \
# 0      29        0       0      0              0      0  0.3  NaN    NaN
# 1      29        0       0      0              0      0  1.6  1.9  128.0
# 2      41        0       0      0              0      0  NaN  NaN    NaN
# 3      36        0       0      0              0      0  NaN  NaN    NaN
# 4      32        0       0      0              0      0  NaN  NaN    NaN
# ...   ...      ...     ...    ...            ...    ...  ...  ...    ...
# 9167   56        0       0      0              0      0  NaN  NaN   64.0
# 9168   22        0       0      0              0      0  NaN  NaN   91.0
# 9169   69        0       0      0              0      0  NaN  NaN  113.0
# 9170   47        0       0      0              0      0  NaN  NaN   75.0
# 9171   31        0       0      0              0      0  NaN  NaN   66.0
#
#        T4U   FTI   TBG
# 0      NaN   NaN   NaN
# 1      NaN   NaN   NaN
# ...

# %%
name0=df['target'].unique().tolist()
name=sorted(name0)
print(name)
N=list(range(len(name)))
normal_mapping=dict(zip(name,N)) 
reverse_mapping=dict(zip(N,name))
df['target']=df['target'].map(normal_mapping)
# Out:
# ['-', 'A', 'AK', 'B', 'C', 'C|I', 'D', 'D|R', 'E', 'F', 'FK', 'G', 'GI', 'GK', 'GKJ', 'H|K', 'I', 'J', 'K', 'KJ', 'L', 'LJ', 'M', 'MI', 'MK', 'N', 'O', 'OI', 'P', 'Q', 'R', 'S']

# %%
target_encoded={j:i for i,j in enumerate(df['target'].unique())}
target=[target_encoded[i] for i in df['target'].values]
target=np.array(target).reshape(-1,1)
target
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [5],
#        [0],
#        [0]])

# %%
target[9149]
# Out:
# array([2])

# %%
target[9158]
# Out:
# array([15])

# %%
import sklearn as sk
from sklearn.preprocessing import StandardScaler

# %%
features= StandardScaler().fit_transform(features)

# %%
features
# Out:
# array([[-0.0376344 , -0.10120978, -0.0961403 , ...,         nan,
#                 nan,         nan],
#        [-0.0376344 , -0.10120978, -0.0961403 , ...,         nan,
#                 nan,         nan],
#        [-0.02749851, -0.10120978, -0.0961403 , ...,         nan,
#                 nan, -0.89642781],
#        ...,
#        [-0.00384811, -0.10120978, -0.0961403 , ...,  1.46716514,
#         -0.59305028,         nan],
#        [-0.02243057, -0.10120978, -0.0961403 , ..., -0.62918238,
#         -0.61711816,         nan],
#        [-0.03594508, -0.10120978, -0.0961403 , ...,  0.21933924,
#         -1.17067919,         nan]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2)

# %%
x_train
# Out:
# array([[-8.91605163e-03, -1.01209777e-01, -9.61403024e-02, ...,
#                     nan,             nan, -4.68880075e-01],
#        [-4.69479138e-04, -1.01209777e-01, -9.61403024e-02, ...,
#          1.11777388e+00, -1.11692864e-01,             nan],
#        [-2.58091966e-02, -1.01209777e-01, -9.61403024e-02, ...,
#         -4.79443270e-01, -1.45949364e+00,             nan],
#        ...,
#        [-3.51004264e-02, -1.01209777e-01, -9.61403024e-02, ...,
#          3.56351265e+00, -5.44914542e-01,             nan],
#        [-3.00324829e-02, -1.01209777e-01, -9.61403024e-02, ...,
#          3.19165307e-01, -6.17118155e-01,             nan],
#        [-4.18576844e-02, -1.01209777e-01, -9.61403024e-02, ...,
#         -6.29182378e-01, -1.35760735e-01,             nan]])

# %%
len(x_train)
# Out:
# 7337

# %%
len(x_test)
# Out:
# 1835

# %%
median = df["TSH"].median()
df["TSH"].fillna(median,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-3379bb8f1b22> in <module>
# ----> 1 median = features["TSH"].median()
#       2 features["TSH"].fillna(median,inplace=True)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
median = df["TT4"].median()
df["TT4"].fillna(median,inplace=True)

# %%
median = df["FTI"].median()
df["FTI"].fillna(median,inplace=True)

# %%
median = df["T3"].median()
df["T3"].fillna(median,inplace=True)

# %%
median = df["T4U"].median()
df["T4U"].fillna(median,inplace=True)

# %%
median = df["TBG"].median()
df["TBG"].fillna(median,inplace=True)

# %%
median = df['sex'].median()
df['age'].fillna(median, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c66afc8c1835> in <module>
# ----> 1 median = df['sex'].median()
#       2 df['age'].fillna(median, inplace=True)
#
# NameError: name 'df' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier
classifer = DecisionTreeClassifier(criterion="entropy", random_state=0)
classifer.fit(x_train,y_train)
y_train= classifer.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-d46388cdb15d> in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 classifer = DecisionTreeClassifier(criterion="entropy", random_state=0)
# ----> 3 classifer.fit(x_train,y_train)
#       4 y_train= classifer.predict(x_train)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
# ...
